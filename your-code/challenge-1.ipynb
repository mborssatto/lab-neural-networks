# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](https://github.com/ironhack-labs/lab-neural-networks/blob/master/your-code/tttboard.jpg?raw=1)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# @title Default title text
import pandas as pd


df = pd.read_csv('/content/tic-tac-toe.csv')
df
# Out:
#     TL TM TR ML MM MR BL BM BR  class
# 0    x  x  x  x  o  o  x  o  o   True
# 1    x  x  x  x  o  o  o  x  o   True
# 2    x  x  x  x  o  o  o  o  x   True
# 3    x  x  x  x  o  o  o  b  b   True
# 4    x  x  x  x  o  o  b  o  b   True
# ..  .. .. .. .. .. .. .. .. ..    ...
# 953  o  x  x  x  o  o  o  x  x  False
# 954  o  x  o  x  x  o  x  o  x  False
# 955  o  x  o  x  o  x  x  o  x  False
# 956  o  x  o  o  x  x  x  o  x  False
# 957  o  o  x  x  x  o  o  x  x  False
#
# [958 rows x 10 columns]

# %%
#Convert the categorical values to numeric in all columns.
from sklearn.preprocessing import LabelEncoder

df_encoded = df.copy()
for col in df_encoded.columns:
  le = LabelEncoder()
  df_encoded[col] = le.fit_transform(df_encoded[col])

df_encoded
# Out:
#      TL  TM  TR  ML  MM  MR  BL  BM  BR  class
# 0     2   2   2   2   1   1   2   1   1      1
# 1     2   2   2   2   1   1   1   2   1      1
# 2     2   2   2   2   1   1   1   1   2      1
# 3     2   2   2   2   1   1   1   0   0      1
# 4     2   2   2   2   1   1   0   1   0      1
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..    ...
# 953   1   2   2   2   1   1   1   2   2      0
# 954   1   2   1   2   2   1   2   1   2      0
# 955   1   2   1   2   1   2   2   1   2      0
# 956   1   2   1   1   2   2   2   1   2      0
# 957   1   1   2   2   2   1   1   2   2      0
#
# [958 rows x 10 columns]

# %%
#Separate the inputs and output.
X = df_encoded.drop('class', axis=1)
y = df_encoded['class']

# %%
#Normalize the input data.
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

print(X_scaled)
# Out:
# [[1.  1.  1.  ... 1.  0.5 0.5]
#  [1.  1.  1.  ... 0.5 1.  0.5]
#  [1.  1.  1.  ... 0.5 0.5 1. ]
#  ...
#  [0.5 1.  0.5 ... 1.  0.5 1. ]
#  [0.5 1.  0.5 ... 1.  0.5 1. ]
#  [0.5 0.5 1.  ... 0.5 1.  1. ]]

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
#Split the training and test data.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

#Create a Sequential model.
import tensorflow as tf

from tensorflow.keras.models import Sequential
model = Sequential()



#Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.

from tensorflow.keras.layers import Dense, Activation
# Corrected Dense layers with 'units' and 'input_shape'
model.add(Dense(units=8, input_shape=(9,)))
model.add(Activation("relu"))

model.add(Dense(units=4))
model.add(Activation("relu"))

model.add(Dense(units=4))
model.add(Activation("relu"))

model.add(Dense(units=2))
model.add(Activation("softmax"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Compile the model using adam as the optimizer and sparse_categorical_crossentropy as the loss function. For metrics, use accuracy for now.
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit the training data.
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6388 - loss: 0.6776 - val_accuracy: 0.6510 - val_loss: 0.6449
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6485 - loss: 0.6330 - val_accuracy: 0.6510 - val_loss: 0.6280
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6358 - loss: 0.6311 - val_accuracy: 0.6510 - val_loss: 0.6208
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6201 - val_accuracy: 0.6771 - val_loss: 0.6074
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7082 - loss: 0.5835 - val_accuracy: 0.6875 - val_loss: 0.6002
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7101 - loss: 0.5685 - val_accuracy: 0.7135 - val_loss: 0.5865
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7564 - loss: 0.5261 - val_accuracy: 0.7240 - val_loss: 0.6048
# Epoch 8/100
# ...

# %%
#Evaluate your neural network model with the test data.
loss_and_metrics = model.evaluate(X_test, y_test, batch_size=32)

#Save your model as tic-tac-toe.model.
model.save('tic-tac-toe.model.keras')

print(loss_and_metrics)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8248 - loss: 0.6654
# [0.6128527522087097, 0.8229166865348816]

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
# Load the saved model
loaded_model = tf.keras.models.load_model('/content/tic-tac-toe.model.keras')

# Select a few random rows from the test dataset
import numpy as np

random_indices = np.random.choice(X_test.shape[0], size=5, replace=False)
random_X_test = X_test[random_indices]
random_y_test = y_test.iloc[random_indices] # Use .iloc for label-based indexing

# Make predictions
predictions = loaded_model.predict(random_X_test)

# Convert predictions to class labels (0 or 1)
predicted_classes = np.argmax(predictions, axis=1)

# Display predictions and actual values
for i in range(len(random_indices)):
    print(f"Sample {random_indices[i]}: Predicted Class = {predicted_classes[i]}, Actual Class = {random_y_test.iloc[i]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Sample 21: Predicted Class = 1, Actual Class = 1
# Sample 3: Predicted Class = 0, Actual Class = 0
# Sample 15: Predicted Class = 0, Actual Class = 1
# Sample 24: Predicted Class = 0, Actual Class = 0
# Sample 98: Predicted Class = 1, Actual Class = 1

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
#Model2 - Adding more layers
model2 = Sequential()


model2.add(Dense(units=8, input_shape=(9,)))
model2.add(Activation("relu"))

model2.add(Dense(units=4))
model2.add(Activation("relu"))

model2.add(Dense(units=4))
model2.add(Activation("relu"))

model2.add(Dense(units=4))
model2.add(Activation("relu"))


model2.add(Dense(units=2))
model2.add(Activation("softmax"))

model2.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit the training data.
model2.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6265 - loss: 0.6607 - val_accuracy: 0.6510 - val_loss: 0.6451
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6476 - loss: 0.6395 - val_accuracy: 0.6510 - val_loss: 0.6448
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6623 - loss: 0.6199 - val_accuracy: 0.6510 - val_loss: 0.6339
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6714 - loss: 0.6069 - val_accuracy: 0.6510 - val_loss: 0.6293
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6535 - loss: 0.6163 - val_accuracy: 0.6510 - val_loss: 0.6240
# ...

# %%
#Evaluate your neural network model with the test data.
loss_and_metrics2 = model2.evaluate(X_test, y_test, batch_size=32)

#Save your model as tic-tac-toe.model.
model2.save('tic-tac-toe.model2.keras')

#comparing metrics
print("Model 1 Metrics:")
print(f"Loss: {loss_and_metrics[0]}, Accuracy: {loss_and_metrics[1]}")

print("\nModel 2 Metrics:")
print(f"Loss: {loss_and_metrics2[0]}, Accuracy: {loss_and_metrics2[1]}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8228 - loss: 0.4652
# Model 1 Metrics:
# Loss: 0.35783979296684265, Accuracy: 0.8645833134651184
#
# Model 2 Metrics:
# Loss: 0.5151644349098206, Accuracy: 0.7916666865348816

# %%
#Model3 - reducing batch size
model3 = Sequential()


model3.add(Dense(units=8, input_shape=(9,)))
model3.add(Activation("relu"))

model3.add(Dense(units=4))
model3.add(Activation("relu"))

model3.add(Dense(units=4))
model3.add(Activation("relu"))


model3.add(Dense(units=2))
model3.add(Activation("softmax"))

model3.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit the training data.
model3.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6229 - loss: 0.6757 - val_accuracy: 0.6510 - val_loss: 0.6475
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6743 - loss: 0.6348 - val_accuracy: 0.6510 - val_loss: 0.6468
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6702 - loss: 0.6349 - val_accuracy: 0.6510 - val_loss: 0.6468
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6648 - loss: 0.6384 - val_accuracy: 0.6510 - val_loss: 0.6470
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6568 - loss: 0.6435 - val_accuracy: 0.6510 - val_loss: 0.6469
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 0.6529 - val_accuracy: 0.6510 - val_loss: 0.6469
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6325 - loss: 0.6593 - val_accuracy: 0.6510 - val_loss: 0.6469
# Epoch 8/100
# ...

# %%
#Evaluate your neural network model with the test data.
loss_and_metrics3 = model3.evaluate(X_test, y_test, batch_size=32)

model3.save('tic-tac-toe.model3.keras')

#comparing metrics
print("Model 1 Metrics:")
print(f"Loss: {loss_and_metrics[0]}, Accuracy: {loss_and_metrics[1]}")

print("\nModel 3 Metrics:")
print(f"Loss: {loss_and_metrics3[0]}, Accuracy: {loss_and_metrics3[1]}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6453 - loss: 0.6504
# Model 1 Metrics:
# Loss: 0.6128527522087097, Accuracy: 0.8229166865348816
#
# Model 3 Metrics:
# Loss: 0.6467993855476379, Accuracy: 0.6510416865348816

# %%
#model4 - increasing learning rate

model4 = Sequential()

model4.add(Dense(units=8, input_shape=(9,)))
model4.add(Activation("relu"))

model4.add(Dense(units=4))
model4.add(Activation("relu"))

model4.add(Dense(units=4))
model4.add(Activation("relu"))

model4.add(Dense(units=2))
model4.add(Activation("softmax"))

model4.compile(optimizer=Adam(learning_rate=0.2), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model4.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5762 - loss: 0.8050 - val_accuracy: 0.6510 - val_loss: 0.6765
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6668 - loss: 0.6658 - val_accuracy: 0.6510 - val_loss: 0.6469
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6408 - loss: 0.6544 - val_accuracy: 0.6510 - val_loss: 0.6474
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6718 - loss: 0.6348 - val_accuracy: 0.6510 - val_loss: 0.6549
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6405 - loss: 0.6585 - val_accuracy: 0.6510 - val_loss: 0.6529
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6635 - loss: 0.6421 - val_accuracy: 0.6510 - val_loss: 0.6493
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6642 - loss: 0.6391 - val_accuracy: 0.6510 - val_loss: 0.6485
# Epoch 8/100
# ...

# %%
#Evaluate your neural network model with the test data.
loss_and_metrics4 = model4.evaluate(X_test, y_test, batch_size=32)

model4.save('tic-tac-toe.model4.keras')

#comparing metrics
print("Model 1 Metrics:")
print(f"Loss: {loss_and_metrics[0]}, Accuracy: {loss_and_metrics[1]}")

print("\nModel 4 Metrics:")
print(f"Loss: {loss_and_metrics4[0]}, Accuracy: {loss_and_metrics4[1]}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6453 - loss: 0.6512
# Model 1 Metrics:
# Loss: 0.6128527522087097, Accuracy: 0.8229166865348816
#
# Model 4 Metrics:
# Loss: 0.6482207179069519, Accuracy: 0.6510416865348816

# %%
model5 = Sequential()

model5.add(Dense(units=8, input_shape=(9,)))
model5.add(Activation("relu"))

model5.add(Dense(units=4))
model5.add(Activation("relu"))

model5.add(Dense(units=4))
model5.add(Activation("relu"))

model5.add(Dense(units=2))
model5.add(Activation("softmax"))

model5.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model5.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5303 - loss: 0.6971 - val_accuracy: 0.6510 - val_loss: 0.6495
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6412 - loss: 0.6525 - val_accuracy: 0.6510 - val_loss: 0.6461
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6465 - loss: 0.6499 - val_accuracy: 0.6510 - val_loss: 0.6454
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6554 - loss: 0.6415 - val_accuracy: 0.6510 - val_loss: 0.6427
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6452 - loss: 0.6450 - val_accuracy: 0.6510 - val_loss: 0.6345
# ...

# %%
#Evaluate your neural network model with the test data.
loss_and_metrics5 = model5.evaluate(X_test, y_test, batch_size=32)

model5.save('tic-tac-toe.model5.keras')

#comparing metrics
print("Model 1 Metrics:")
print(f"Loss: {loss_and_metrics[0]}, Accuracy: {loss_and_metrics[1]}")

print("\nModel 5 Metrics:")
print(f"Loss: {loss_and_metrics5[0]}, Accuracy: {loss_and_metrics5[1]}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7904 - loss: 0.5669
# Model 1 Metrics:
# Loss: 0.6128527522087097, Accuracy: 0.8229166865348816
#
# Model 5 Metrics:
# Loss: 0.5789440870285034, Accuracy: 0.7760416865348816

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %%
#All approaches decreased performance compared to the first run.
But we saw an increase in quality by increasing the number of epochs.
I tried:
- adding a new layer
- decreasing batch size (from 32 to 16)
- increasing learning rate (from 0.01 to 0.2)
- increasing number of epochs (from 100 to 200)
